# %% [markdown]
# # 可选实验：Python和Jupyter Notebook简介
# 欢迎来到第一个可选实验！
# 可选实验的用途包括：
# - 提供信息 - 如本笔记本
# - 通过实际示例强化讲座内容
# - 提供评分实验中使用的例程的工作示例

# %% [markdown]
# ## 目标
# 在本实验中，您将：
# - 获得Jupyter笔记本的简要介绍
# - 浏览Jupyter笔记本
# - 了解markdown单元格和代码单元格的区别
# - 练习一些基础Python

# %% [markdown]
# 熟悉Jupyter笔记本最简单的方法是使用帮助菜单中提供的导览：

# %% [markdown]
# <figure>
#     <center> <img src="./images/C1W1L1_Tour.PNG"  alt='missing' width="400"  ><center/>
# <figure/>

# %% [markdown]
# Jupyter笔记本有两种类型的单元格在本课程中使用。像这样包含文档的单元格称为`Markdown单元格`。该名称来源于单元格中使用的简单格式化语言。您不需要创建markdown单元格。了解下图所示的`单元格下拉菜单`很有用。有时，单元格可能会进入错误的模式，您可能需要将其恢复到正确状态：

# %% [markdown]
# <figure>
#    <img src="./images/C1W1L1_Markdown.PNG"  alt='missing' width="400"  >
# <figure/>

# %% [markdown]
# 另一种类型的单元格是`代码单元格`，您将在其中编写代码：

# %%
#这是一个'代码'单元格
print("This is  code cell")
# Out:
# This is  code cell

# %% [markdown]
# ## Python
# 您可以在代码单元格中编写代码。
# 要运行代码，请选择单元格并
# - 按住shift键并按'enter'或'return'键
# - 点击上方的'运行'箭头
# <figure>
#     <img src="./images/C1W1L1_Run.PNG"  width="400"  >
# <figure/>

# %% [markdown]
# ### Print语句
# Print语句通常使用Python f-string风格。
# 尝试在下面的单元格中创建自己的print。
# 尝试两种运行单元格的方法。

# %%
# print语句
variable = "right in the strings!"
print(f"f strings allow you to embed variables {variable}")
# Out:
# f strings allow you to embed variables right in the strings!

# %% [markdown]
# # 恭喜！
# 您现在知道如何使用Jupyter笔记本了。
