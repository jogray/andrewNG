# %% [markdown]
# # 可选实验：分类
#
# 在本实验中，你将对比回归和分类。

# %%
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from lab_utils_common import dlc, plot_data
from plt_one_addpt_onclick import plt_one_addpt_onclick
plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# ## 分类问题
# <img align="left" src="./images/C1_W3_Classification.png"     style=" width:380px; padding: 10px; " > 分类问题的例子包括：将邮件识别为垃圾邮件或非垃圾邮件，或者判断肿瘤是恶性还是良性。特别是，这些是*二元*分类的例子，其中有两个可能的结果。结果可以用'正'/'负'对来描述，如'是'/'否'、'真'/'假'或'1'/'0'。
#
# 分类数据集的绘图通常使用符号来表示示例的结果。在下面的图中，'X'用于表示正值，而'O'表示负结果。

# %%
x_train = np.array([0., 1, 2, 3, 4, 5])
y_train = np.array([0,  0, 0, 1, 1, 1])
X_train2 = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train2 = np.array([0, 0, 0, 1, 1, 1])

# %%
pos = y_train == 1
neg = y_train == 0

fig,ax = plt.subplots(1,2,figsize=(8,3))
#图1，单变量
ax[0].scatter(x_train[pos], y_train[pos], marker='x', s=80, c = 'red', label="y=1")
ax[0].scatter(x_train[neg], y_train[neg], marker='o', s=100, label="y=0", facecolors='none', 
              edgecolors=dlc["dlblue"],lw=3)

ax[0].set_ylim(-0.08,1.1)
ax[0].set_ylabel('y', fontsize=12)
ax[0].set_xlabel('x', fontsize=12)
ax[0].set_title('one variable plot')
ax[0].legend()

#图2，双变量
plot_data(X_train2, y_train2, ax[1])
ax[1].axis([0, 4, 0, 4])
ax[1].set_ylabel('$x_1$', fontsize=12)
ax[1].set_xlabel('$x_0$', fontsize=12)
ax[1].set_title('two variable plot')
ax[1].legend()
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# 注意上图中：
# - 在单变量图中，正值结果显示为红色'X'和y=1。负值结果是蓝色'O'，位于y=0处。
#    - 回忆一下，在线性回归的情况下，y不会被限制为两个值，而可以是任何值。
# - 在双变量图中，y轴不可用。正值结果显示为红色'X'，而负值结果使用蓝色'O'符号。
#     - 回忆一下，在多变量线性回归的情况下，y不会被限制为两个值，类似的图将是三维的。

# %% [markdown]
# ## 线性回归方法
# 在上一周，你应用线性回归构建了预测模型。让我们在这里尝试使用讲座中描述的简单示例。该模型将基于肿瘤大小预测肿瘤是良性还是恶性。尝试以下操作：
# - 点击'运行线性回归'以找到给定数据的最佳线性回归模型。
#     - 注意 resulting linear model does **not** match the data well.
# 改进结果的一个选项是应用*阈值*。
# - 勾选'切换0.5阈值'框以显示应用阈值后的预测。
#     - 这些预测看起来很好，预测与数据匹配
# - *重要*：现在，在右侧远处添加更多'恶性'数据点，在大肿瘤大小范围（接近10），并重新运行线性回归。
#     - 现在，模型预测了较大的肿瘤，但x=3处的数据点被错误预测！
# - 要清除/刷新图，请重新运行包含绘图命令的单元格。

# %%
w_in = np.zeros((1))
b_in = 0
plt.close('all') 
addpt = plt_one_addpt_onclick( x_train,y_train, w_in, b_in, logistic=False)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# 上面的例子表明，线性模型不足以对分类数据进行建模。该模型可以如下面的实验室所述进行扩展。

# %% [markdown]
# ## 恭喜！
# 在本实验中，你：
# - 探索了分类数据集和绘图
# - 确定了线性回归不足以解决分类问题。
